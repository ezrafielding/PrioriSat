# %%
from DOTA_devkit import DOTA
import matplotlib.pyplot as plt

# %%
dota = DOTA.DOTA('./datasets/DOTAv1.5/Validation/')

# %%
classnames = ['plane', 'baseball-diamond', 'bridge', 'ground-track-field', 'small-vehicle', 'large-vehicle', 'ship', 'tennis-court',
                'basketball-court', 'storage-tank',  'soccer-ball-field', 'roundabout', 'harbor', 'swimming-pool', 'helicopter', 'container-crane']
imgIDs = dota.getImgIds()

# %%
imgids = dota.getImgIds(catNms=['ship'])[:10]
img = dota.loadImgs(imgids)
for imgid in imgids:
    print(imgid)
    anns = dota.loadAnns(imgId=imgid)
    dota.showAnns(anns, imgid, 2)
    plt.show()
# Out:
# isarralike: True
# imgids: ['P0128', 'P0789', 'P0300', 'P1623', 'P1380', 'P1278', 'P0864', 'P1234', 'P2059', 'P1283']
# filename: ./datasets/DOTA_Dataset/Validation/images/P0128.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P0789.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P0300.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P1623.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P1380.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P1278.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P0864.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P1234.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P2059.png
# filename: ./datasets/DOTA_Dataset/Validation/images/P1283.png
# P0128
# isarralike: False
# imgids: ['P0128']
# filename: ./datasets/DOTA_Dataset/Validation/images/P0128.png
# P0789
# isarralike: False
# imgids: ['P0789']
# filename: ./datasets/DOTA_Dataset/Validation/images/P0789.png
# P0300
# ...
